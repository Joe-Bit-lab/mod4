# %%
import pandas as pd
import numpy as np
import missingno as msno

# %%
zill = pd.read_csv('../data/raw/zillow_data.csv')

# %%
zill.shape
# Out:
# (14723, 272)

# %%
zill.columns
# Out:
# Index(['RegionID', 'RegionName', 'City', 'State', 'Metro', 'CountyName',
#        'SizeRank', '1996-04', '1996-05', '1996-06',
#        ...
#        '2017-07', '2017-08', '2017-09', '2017-10', '2017-11', '2017-12',
#        '2018-01', '2018-02', '2018-03', '2018-04'],
#       dtype='object', length=272)

# %%
# msno.matrix(zill);

# %%
pd.options.display.max_rows
# Out:
# 60

# %%
pd.options.display.max_columns
# Out:
# 20

# %%
# for c in zill.columns:
#     nulls = zill[c].isnull().sum()
#     if nulls != 0:
#         print('Column: {} is {}% null with {} values'.format(c, round(nulls/14723, 3), nulls))
#     else:
#         pass

# %%
zill.iloc[:, 7:zill.shape[1]].columns
# Out:
# Index(['1996-04', '1996-05', '1996-06', '1996-07', '1996-08', '1996-09',
#        '1996-10', '1996-11', '1996-12', '1997-01',
#        ...
#        '2017-07', '2017-08', '2017-09', '2017-10', '2017-11', '2017-12',
#        '2018-01', '2018-02', '2018-03', '2018-04'],
#       dtype='object', length=265)

# %%
count = 0

for c in zill.iloc[:, 7:zill.shape[1]].columns:
    nulls = zill[c].isnull().sum()
    if nulls != 0:
        print('Column: {} is {}% null with {} values'.format(c, round(nulls/14723, 3), nulls))
        count += 1
    else:
        count += 1
        
print(count)
# Out:
# Column: 1996-04 is 0.071% null with 1039 values
# Column: 1996-05 is 0.071% null with 1039 values
# Column: 1996-06 is 0.071% null with 1039 values
# Column: 1996-07 is 0.071% null with 1039 values
# Column: 1996-08 is 0.071% null with 1039 values
# Column: 1996-09 is 0.071% null with 1039 values
# Column: 1996-10 is 0.071% null with 1039 values
# Column: 1996-11 is 0.071% null with 1039 values
# Column: 1996-12 is 0.071% null with 1039 values
# Column: 1997-01 is 0.071% null with 1039 values
# Column: 1997-02 is 0.071% null with 1039 values
# Column: 1997-03 is 0.071% null with 1039 values
# Column: 1997-04 is 0.071% null with 1039 values
# Column: 1997-05 is 0.071% null with 1039 values
# Column: 1997-06 is 0.071% null with 1039 values
# Column: 1997-07 is 0.071% null with 1038 values
# Column: 1997-08 is 0.071% null with 1038 values
# Column: 1997-09 is 0.071% null with 1038 values
# Column: 1997-10 is 0.071% null with 1038 values
# Column: 1997-11 is 0.071% null with 1038 values
# ...

# %%
# msno.heatmap(zill);

# %%
def null_mean(this_col_mean, prior_col_mean):
    return this_col_mean * (prior_col_mean / this_col_mean)

# %%
zill.loc[(zill.iloc[:, 271].isnull() == True)]
# Out:
# Empty DataFrame
# Columns: [RegionID, RegionName, City, State, Metro, CountyName, SizeRank, 1996-04, 1996-05, 1996-06, 1996-07, 1996-08, 1996-09, 1996-10, 1996-11, 1996-12, 1997-01, 1997-02, 1997-03, 1997-04, 1997-05, 1997-06, 1997-07, 1997-08, 1997-09, 1997-10, 1997-11, 1997-12, 1998-01, 1998-02, 1998-03, 1998-04, 1998-05, 1998-06, 1998-07, 1998-08, 1998-09, 1998-10, 1998-11, 1998-12, 1999-01, 1999-02, 1999-03, 1999-04, 1999-05, 1999-06, 1999-07, 1999-08, 1999-09, 1999-10, 1999-11, 1999-12, 2000-01, 2000-02, 2000-03, 2000-04, 2000-05, 2000-06, 2000-07, 2000-08, 2000-09, 2000-10, 2000-11, 2000-12, 2001-01, 2001-02, 2001-03, 2001-04, 2001-05, 2001-06, 2001-07, 2001-08, 2001-09, 2001-10, 2001-11, 2001-12, 2002-01, 2002-02, 2002-03, 2002-04, 2002-05, 2002-06, 2002-07, 2002-08, 2002-09, 2002-10, 2002-11, 2002-12, 2003-01, 2003-02, 2003-03, 2003-04, 2003-05, 2003-06, 2003-07, 2003-08, 2003-09, 2003-10, 2003-11, 2003-12, ...]
# Index: []
#
# [0 rows x 272 columns]

# %%
zill.iloc[:, 271]
# Out:
# 0        1030600
# 1         321800
# 2         329900
# 3        1307000
# 4         121500
#           ...
# 14718     209300
# 14719     225800
# 14720     133400
# 14721     664400
# 14722     357200
# Name: 2018-04, Length: 14723, dtype: int64

# %%
zill.iloc[:, 7]
# Out:
# 0        334200.0
# 1        235700.0
# 2        210400.0
# 3        498100.0
# 4         77300.0
#            ...
# 14718     94600.0
# 14719     92700.0
# 14720     57100.0
# 14721    191100.0
# 14722    176400.0
# Name: 1996-04, Length: 14723, dtype: float64

# %%
value_cols = list(range(7, 272))

# %%
for c in value_cols:

# %%
#     for cell in zill[:, i]:
#         print(i)
#     else:
#         print(i)
        
        
        
        
        
        
#         if cell.isnull() == True:
#             print('Null Value')
# #             cell = null_mean(zill.iloc[:, i].mean(), zill.iloc[:, i-1].mean())
#             i -= 1
#         else:
#             i -= 1

# %%
zill
# Out:
#        RegionID  RegionName                 City State              Metro  \
# 0         84654       60657              Chicago    IL            Chicago
# 1         90668       75070             McKinney    TX  Dallas-Fort Worth
# 2         91982       77494                 Katy    TX            Houston
# 3         84616       60614              Chicago    IL            Chicago
# 4         93144       79936              El Paso    TX            El Paso
# ...         ...         ...                  ...   ...                ...
# 14718     58333        1338             Ashfield    MA    Greenfield Town
# 14719     59107        3293            Woodstock    NH          Claremont
# 14720     75672       40404                Berea    KY           Richmond
# 14721     93733       81225  Mount Crested Butte    CO                NaN
# 14722     95851       89155             Mesquite    NV          Las Vegas
#
#       CountyName  SizeRank   1996-04   1996-05   1996-06  ...  2017-07  \
# ...

# %%
count = 0

for c in zill.iloc[:, 7:zill.shape[1]].columns:
    nulls = zill[c].isnull().sum()
    if nulls != 0:
        print('Column: {} is {}% null with {} values'.format(c, round(nulls/14723, 3), nulls))
        count += 1
    else:
        count += 1
        
print(count)
# Out:
# Column: 1996-04 is 0.071% null with 1039 values
# Column: 1996-05 is 0.071% null with 1039 values
# Column: 1996-06 is 0.071% null with 1039 values
# Column: 1996-07 is 0.071% null with 1039 values
# Column: 1996-08 is 0.071% null with 1039 values
# Column: 1996-09 is 0.071% null with 1039 values
# Column: 1996-10 is 0.071% null with 1039 values
# Column: 1996-11 is 0.071% null with 1039 values
# Column: 1996-12 is 0.071% null with 1039 values
# Column: 1997-01 is 0.071% null with 1039 values
# Column: 1997-02 is 0.071% null with 1039 values
# Column: 1997-03 is 0.071% null with 1039 values
# Column: 1997-04 is 0.071% null with 1039 values
# Column: 1997-05 is 0.071% null with 1039 values
# Column: 1997-06 is 0.071% null with 1039 values
# Column: 1997-07 is 0.071% null with 1038 values
# Column: 1997-08 is 0.071% null with 1038 values
# Column: 1997-09 is 0.071% null with 1038 values
# Column: 1997-10 is 0.071% null with 1038 values
# Column: 1997-11 is 0.071% null with 1038 values
# ...

# %%
f
# Out:
#        RegionID  RegionName                 City State              Metro  \
# 0         84654       60657              Chicago    IL            Chicago
# 1         90668       75070             McKinney    TX  Dallas-Fort Worth
# 2         91982       77494                 Katy    TX            Houston
# 3         84616       60614              Chicago    IL            Chicago
# 4         93144       79936              El Paso    TX            El Paso
# ...         ...         ...                  ...   ...                ...
# 14718     58333        1338             Ashfield    MA    Greenfield Town
# 14719     59107        3293            Woodstock    NH          Claremont
# 14720     75672       40404                Berea    KY           Richmond
# 14721     93733       81225  Mount Crested Butte    CO                NaN
# 14722     95851       89155             Mesquite    NV          Las Vegas
#
#       CountyName  SizeRank   1996-04   1996-05   1996-06  ...  2017-07  \
# ...
